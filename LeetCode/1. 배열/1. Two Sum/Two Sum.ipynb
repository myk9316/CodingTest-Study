# %% [markdown]
# # Two Sum
# - 코드출처: 파이썬 알고리즘 인터뷰 (by 박상길)

# %%
from IPython.display import Image
Image("./문제설명.png")

# %% [markdown]
# ## 브루트 포스로 계산

# %%
def twoSum(nums, target):
    for i in range(len(nums)):
        for j in range(i+1, len(nums)):
            if nums[i] + nums[j] == target:
                return [i, j]

# %%
print(twoSum([2, 7, 11, 15], 9))
print(twoSum([3, 2, 4], 6))
print(twoSum([3, 3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## in을 이용한 탐색

# %%
def twoSum(nums, target):
    for i, n in enumerate(nums):
        complement = target - n
        
        if complement in nums[i + 1:]:
            return [nums.index(n), nums[i + 1:].index(complement) + (i + 1)]

# %%
print(twoSum([2, 7, 11, 15], 9))
print(twoSum([3, 2, 4], 6))
print(twoSum([3, 3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## 첫 번째 수를 뺀 결과 키 조회

# %%
def twoSum(nums, target):
    nums_map = {}
    # 키와 값을 바꿔서 딕셔너리로 저장
    for i, num in enumerate(nums):
        nums_map[num] = i
        
    # 타겟에서 첫 번째 수를 뺀 결과를 키로 조회
    for i, num in enumerate(nums):
        if target - num in nums_map and i != nums_map[target - num]:
            return [i, nums_map[target - num]]

# %%
print(twoSum([2, 7, 11, 15], 9))
print(twoSum([3, 2, 4], 6))
print(twoSum([3, 3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## 조회 구조 개선

# %%
def twoSum(nums, target):
    nums_map = {}
    for i, num in enumerate(nums):
        if target - num in nums_map:
            return [nums_map[target - num], i]
        nums_map[num] = i

# %%
print(twoSum([2, 7, 11, 15], 9))
print(twoSum([3, 2, 4], 6))
print(twoSum([3, 3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## 투 포인터 이용 --> 풀이 불가능

# %%
def twoSum(nums, target):
    nums = sorted(nums)
    left, right = 0, len(nums) - 1
    while not left == right:
        # 합이 타겟보다 작으면 왼쪽포인터를 오른쪽으로
        if nums[left] + nums[right] < target:
            left += 1
        
        # 합이 타겟보다 크면 오른쪽포인터를 왼쪽으로
        elif nums[left] + nums[right] > target:
            right += 1
        
        else:
            return [left, right]

# %%
print(twoSum([2, 7, 11, 15], 9))
print(twoSum([3, 2, 4], 6))
print(twoSum([3, 3], 6))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-24941bacf06e> in <module>
# ----> 1 print(twoSum([2, 7, 11, 15], 9))
#       2 print(twoSum([3, 2, 4], 6))
#       3 print(twoSum([3, 3], 6))
#
# <ipython-input-39-3594dbc597f2> in twoSum(nums, target)
#       4     while not left == right:
#       5         # 합이 타겟보다 작으면 왼쪽포인터를 오른쪽으로
# ----> 6         if nums[left] + nums[right] < target:
#       7             left += 1
#       8
#
# IndexError: list index out of range
