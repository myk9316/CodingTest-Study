# %% [markdown]
# # 두 정수 사이의 합

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(a,b):
    start = min(a,b)
    end = max(a,b)

    return sum(range(start, end+1))

# %%
print(solution(3,5))
print(solution(3,3))
print(solution(5,3))
# Out:
# 12
# 3
# 12
