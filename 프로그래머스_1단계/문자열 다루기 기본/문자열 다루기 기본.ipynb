# %% [markdown]
# # 문자열 다루기 기본

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(s):
    return (len(s)==4 or len(s)== 6) and s.isdigit()

# %%
print(solution("a234"))
print(solution("1234"))
# Out:
# False
# True
