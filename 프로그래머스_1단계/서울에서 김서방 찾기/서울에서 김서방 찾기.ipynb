# %% [markdown]
# # 서울에서 김서방 찾기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(seoul):
    return '김서방은 {0}에 있다'.format(seoul.index('Kim'))

# %%
solution(["Jane", "Kim"])
# Out:
# '김서방은 1에 있다'
