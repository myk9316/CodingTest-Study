# %% [markdown]
# #  직사각형 별찍기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
a, b = map(int, input().strip().split(' '))

for i in range(b):
    print(a*'*')
# Out:
# 5 3
# *****
# *****
# *****
