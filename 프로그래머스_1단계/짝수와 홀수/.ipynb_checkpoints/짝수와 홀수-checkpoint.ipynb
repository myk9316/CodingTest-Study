# %% [markdown]
# # 짝수와 홀수

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(num):
    if num % 2 == 0:
        return 'Even'
    else:
        return 'Odd'

# %%
print(solution(3))
print(solution(4))
# Out:
# Odd
# Even
