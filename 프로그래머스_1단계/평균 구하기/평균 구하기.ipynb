# %% [markdown]
# # 평균 구하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(arr):
    return sum(arr) / len(arr)

# %%
print(solution([1,2,3,4]))
print(solution([5,5]))
# Out:
# 2.5
# 5.0
