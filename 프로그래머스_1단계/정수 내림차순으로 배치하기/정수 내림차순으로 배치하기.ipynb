# %% [markdown]
# # 정수 내림차순으로 배치하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    answer = ''
    n = list(str(n))
    n = sorted(n, reverse=True)
    return int("".join(n))

# %%
solution(118372)
# Out:
# 873211
