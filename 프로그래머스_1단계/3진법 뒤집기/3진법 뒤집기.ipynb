# %% [markdown]
# # 3진법 뒤집기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    answer =''
    
    while n > 0:
        n, re = divmod(n, 3)
        answer += str(re)
    
    return int(answer, 3)

# %%
print(solution(45))
print(solution(125))
# Out:
# 7
# 229
