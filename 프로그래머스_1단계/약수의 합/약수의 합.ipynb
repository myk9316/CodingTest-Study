# %% [markdown]
# # 약수의 합

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    return sum([x for x in range(1, n+1) if n%x==0])

# %%
print(solution(12))
print(solution(5))
# Out:
# 28
# 6
