# %% [markdown]
# # 폰켓몬

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(nums):
    max_pok_num = len(set(nums))
    return min(max_pok_num, len(nums)//2)

# %%
print(solution([3,1,2,3]))
print(solution([3,3,3,2,2,4]))
print(solution([3,3,3,2,2,2]))
# Out:
# 2
# 3
# 2
