# %% [markdown]
# # 자연수 뒤집어 배열로 만들기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    n = str(n)[::-1]
    
    return list(map(int, n))

# %%
print(solution(12345))
# Out:
# [5, 4, 3, 2, 1]
