# %% [markdown]
# # 부족한 금액 계산하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(price, money, count):
    need = sum([i*price for i in range(count+1)]) - money
    return need if need > 0 else 0

# %%
print(solution(3, 20, 4))
# Out:
# 10
