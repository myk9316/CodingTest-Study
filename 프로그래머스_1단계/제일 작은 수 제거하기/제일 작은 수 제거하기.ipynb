# %% [markdown]
# # 제일 작은 수 제거하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(arr):
    if len(arr)>1:
        arr.remove(min(arr))
        return arr
    else:
        return [-1]

# %%
print(solution([4,3,2,1]))
print(solution([10]))
# Out:
# [4, 3, 2]
# [-1]
