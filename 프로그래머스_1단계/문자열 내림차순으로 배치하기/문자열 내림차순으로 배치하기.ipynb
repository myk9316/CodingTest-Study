# %% [markdown]
# # 문자열 내림차순으로 배치하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(s):
    return ''.join(sorted(s, reverse=True))

# %%
print(solution("Zbcdefg"))
# Out:
# gfedcbZ
