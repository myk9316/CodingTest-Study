# %% [markdown]
# # x만큼 간격이 있는 n개의 숫자

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(x, n):
    return [i * x for i in range(1, n+1)]

# %%
print(solution(2, 5))
print(solution(4, 3))
print(solution(-4, 2))
# Out:
# [2, 4, 6, 8, 10]
# [4, 8, 12]
# [-4, -8]
