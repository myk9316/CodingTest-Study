# %% [markdown]
# # 자릿수 더하기

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    return sum(map(int, str(n)))

# %%
print(solution(123))
print(solution(987))
# Out:
# 6
# 24
