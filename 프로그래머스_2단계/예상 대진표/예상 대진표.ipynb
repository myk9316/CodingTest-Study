# %% [markdown]
# # 예상 대진표

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n,a,b):
    answer = 0
    while a != b:
        a = (a+1)//2
        b = (b+1)//2
        answer += 1
        
    return answer

# %%
print(solution(8, 4, 7))
# Out:
# 3

# %%
# Out:
# 3
