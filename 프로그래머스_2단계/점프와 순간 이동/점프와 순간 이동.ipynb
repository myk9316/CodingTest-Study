# %% [markdown]
# # 점프와 순간 이동

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
def solution(n):
    ans = 0
    
    while n>0:
        ans += n % 2
        n //= 2
    
    return ans

# %%
print(solution(5))
print(solution(6))
print(solution(5000))
# Out:
# 2
# 2
# 5

# %%
def solution(n):
    ans = 0
    
    while n > 0:
        ans += n%2
        n //= 2
        
    return ans

# %%
print(solution(5))
print(solution(6))
print(solution(5000))
# Out:
# 2
# 2
# 5

# %%
1%2
# Out:
# 1
