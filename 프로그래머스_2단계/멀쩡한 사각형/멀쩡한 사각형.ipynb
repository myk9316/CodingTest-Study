# %% [markdown]
# # 멀쩡한 사각형

# %%
from IPython.display import Image
Image("./문제설명.png")

# %%
import math

def solution(w,h):
    return (w*h) - (w+h - math.gcd(w, h))

# %%
print(solution(8, 12))
# Out:
# 80
